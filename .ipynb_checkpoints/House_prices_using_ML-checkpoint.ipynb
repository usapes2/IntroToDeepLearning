# %%
import pandas as pd
import webbrowser
import os

data_table = pd.read_csv('data/ml_house_data_set.csv')

html = data_table[0:100].to_html()

# save to temp file
with open('data.html', 'w') as f:
    f.write(html)
    
# open the web page in our web browswer
full_filename = os.path.abspath('data.html')
webbrowser.open('file://{}'.format(full_filename))
# Out:
# True

# %%
data_table.head(10)
# Out:
#    year_built  stories  num_bedrooms  full_bathrooms  half_bathrooms  \
# 0        1978        1             4               1               1
# 1        1958        1             3               1               1
# 2        2002        1             3               2               0
# 3        2004        1             4               2               0
# 4        2006        1             4               2               0
# 5        2005        1             3               2               0
# 6        1979        1             3               2               1
# 7        1958        1             5               2               0
# 8        1958        1             5               2               0
# 9        1961        1             1               1               0
#
#    livable_sqft  total_sqft garage_type  garage_sqft  carport_sqft  \
# 0          1689        1859    attached          508             0
# 1          1984        2002    attached          462             0
# 2          1581        1578        none            0           625
# 3          1829        2277    attached          479             0
# 4          1580        1749    attached          430             0
# 5          1621        1672    attached          430             0
# 6          2285        2365    detached          532             0
# 7          1745        1741        none            0             0
# 8          1747        1745        none            0             0
# 9           998        1161        none            0           242
#
#    has_fireplace  has_pool  has_central_heating  has_central_cooling  \
# 0           True     False                 True                 True
# 1           True     False                 True                 True
# 2          False     False                 True                 True
# 3           True     False                 True                 True
# 4           True     False                 True                 True
# 5           True     False                 True                 True
# 6           True     False                 True                 True
# 7          False     False                False                False
# 8          False     False                False                False
# 9          False     False                False                False
#
#    house_number       street_name  unit_number                city  zip_code  \
# 0         42670    Lopez Crossing          NaN            Hallfort     10907
# 1          5194      Gardner Park          NaN            Hallfort     10907
# 2          4366   Harding Islands          NaN  Lake Christinaport     11203
# 3          3302  Michelle Highway          NaN  Lake Christinaport     11203
# 4           582        Jacob Cape          NaN  Lake Christinaport     11203
# 5         78445  Michelle Highway          NaN  Lake Christinaport     11203
# 6           246    Harris Estates          NaN          Morrisport     10924
# 7         35725      Jessica Isle          NaN  Lake Christinaport     11203
# 8         35725      Jessica Isle          NaN  Lake Christinaport     11203
# 9         73327     Kurt Crescent          NaN  Lake Christinaport     11203
#
#    sale_price
# 0    270897.0
# 1    302404.0
# 2   2519996.0
# 3    197193.0
# 4    207897.0
# 5    196559.0
# 6    434697.0
# 7     64887.0
# 8    143636.0
# 9     81896.0
